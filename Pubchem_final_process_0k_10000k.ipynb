# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data1=pd.read_csv('/content/drive/MyDrive/pubchem_raw_0k_1000k.csv')
data2=pd.read_csv('/content/drive/MyDrive/pubchem_raw_1000k_2000k.csv')
data3=pd.read_csv('/content/drive/MyDrive/pubchem_raw_2000k_3000k.csv')
data4=pd.read_csv('/content/drive/MyDrive/pubchem_raw_3000k_4000k.csv')
data5=pd.read_csv('/content/drive/MyDrive/pubchem_raw_4000k_5000k.csv')
data6=pd.read_csv('/content/drive/MyDrive/pubchem_raw_5000k_6000k.csv')
data7=pd.read_csv('/content/drive/MyDrive/pubchem_raw_6000k_7000k.csv')
data8=pd.read_csv('/content/drive/MyDrive/pubchem_raw_7000k_8000k.csv')
data9=pd.read_csv('/content/drive/MyDrive/pubchem_raw_8000k_9000k.csv')
data10=pd.read_csv('/content/drive/MyDrive/pubchem_raw_9000k_10000k.csv')

# %%
frames=(data1,data2,data3,data4,data5,data6,data7,data8,
            data9,data10)

# %%
final_data_raw=pd.concat(frames)

# %%
final_data_raw.shape
# Out:
# (62169, 5)

# %%
final_data_raw.to_csv('/content/drive/MyDrive/Pubchem_raw_0k_10000k.csv')

# %%
data11=pd.read_csv('/content/drive/MyDrive/pubchem_clean_0k_1000k.csv')
data12=pd.read_csv('/content/drive/MyDrive/pubchem_clean_1000k_2000k.csv')
data13=pd.read_csv('/content/drive/MyDrive/pubchem_clean_2000k_3000k.csv')
data14=pd.read_csv('/content/drive/MyDrive/pubchem_clean_3000k_4000k.csv')
data15=pd.read_csv('/content/drive/MyDrive/pubchem_clean_4000k_5000k.csv')
data16=pd.read_csv('/content/drive/MyDrive/pubchem_clean_5000k_6000k.csv')
data17=pd.read_csv('/content/drive/MyDrive/pubchem_clean_6000k_7000k.csv')
data18=pd.read_csv('/content/drive/MyDrive/pubchem_clean_7000k_8000k.csv')
data19=pd.read_csv('/content/drive/MyDrive/pubchem_clean_8000k_9000k.csv')
data20=pd.read_csv('/content/drive/MyDrive/pubchem_clean_9000k_10000k.csv')

# %%
frames1=(data11,data12,data13,data14,data15,data16,data17,data18,
            data19,data20)

# %%
final_data_clean=pd.concat(frames1)

# %%
final_data_clean.shape
# Out:
# (20769, 7)

# %%
final_data_clean
# Out:
#      Unnamed: 0  index                                             SMILES  \
# 0             0      0                                            CC(CN)O
# 1             1      1          C1=CC(=C(C=C1[N+](=O)[O-])[N+](=O)[O-])Cl
# 2             2      2                                           C(CCl)Cl
# 3             3      4                          C1=CC(=C(C(=C1)O)O)C(=O)O
# 4             4      5                                           C(C=O)Cl
# ..          ...    ...                                                ...
# 110         110    173  CC[C@H](C)[C@@H]1[C@H](C=C[C@@]2(O1)C[C@@H]3C[...
# 111         111    176  CS(=O)(=O)C1=C(C(=C(C=C1)C(=O)C2C(=O)CCCC2=O)C...
# 112         112    177  CCOC1=C(C=CC(=C1)[C@@H](CS(=O)(=O)C)N2C(=O)C3=...
# 113         113    179                                      C=CCCCCCN=C=S
# 114         114    180                         C1CNCC2=C1NC3=CC=CC=C23.Cl
#
#                      SOLUBILITY  sol_new1   Unit  sol_final
# ...

# %%
final_data_clean.to_csv('/content/drive/MyDrive/Pubchem_clean_0k_10000k_clean.csv')
